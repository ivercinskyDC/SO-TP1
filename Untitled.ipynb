# %%
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt
import seaborn as sns; sns.set_style("darkgrid")
from scipy import stats

# %%
df = pd.read_csv('resultadosThreads', sep=';')
sns.tsplot(time=df['Threads'], data=df['Normal'], interpolate=False, color="blue",value = 'Tiempo(Nanosegundos)')
sns.tsplot(time=df['Threads'], data=df['Concurrent'], interpolate=False, color="green")

plt.show()
